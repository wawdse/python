# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
image = np.array(Image.open('../data/cat.png'))

# %%
plt.imshow(image)
plt.axis('off')
plt.show()

# %%
files = ['../data/dog.png', '../data/cat.png']
images = [np.array(Image.open(file)) for file in files]

# %%
for image in images:
    plt.imshow(image)
    plt.axis('off')
    plt.show()
